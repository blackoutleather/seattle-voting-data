# %%
import helper
import geopandas as gpd
import pyproj

# %%
pyproj.datadir.get_data_dir()
# Out:
# '/Users/devin.wilkinson/opt/anaconda3/envs/untitled1/share/proj'

# %%
# Out:
# # packages in environment at /Users/devin.wilkinson/opt/anaconda3/envs/untitled1:
# #
# # Name                    Version                   Build  Channel
# abseil-cpp                20210324.0           he49afe7_0    conda-forge
# aiobotocore               1.2.2              pyhd3eb1b0_0
# aiohttp                   3.7.4            py38h96a0964_0    conda-forge
# aioitertools              0.7.1              pyhd8ed1ab_0    conda-forge
# altair                    4.1.0                      py_1    conda-forge
# appnope                   0.1.2            py38h50d1736_1    conda-forge
# argh                      0.26.2          pyh9f0ad1d_1002    conda-forge
# argon2-cffi               20.1.0           py38h5406a74_2    conda-forge
# arrow-cpp                 4.0.0           py38hbb63ffc_0_cpu    conda-forge
# astor                     0.8.1              pyh9f0ad1d_0    conda-forge
# async-timeout             3.0.1                   py_1000    conda-forge
# ...

# %%
precincts = helper.get_seattle_precinct()
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-8-0ac7775cb160> in <module>
# ----> 1 precincts = helper.get_seattle_precinct()
#
# ~/PycharmProjects/pythonProject1/helper.py in get_seattle_precinct()
#      30
#      31 def get_seattle_precinct():
# ---> 32     kc = get_kc_precinct_gdf()
#      33     return kc[kc.name.str.startswith("SEA ")]
#      34
#
# ~/PycharmProjects/pythonProject1/helper.py in get_kc_precinct_gdf()
#      24     path2 = "/Users/devin.wilkinson/Downloads/Voting_Districts_of_King_County___votdst_area (2).csv"
#      25
# ---> 26     df = gpd.read_file(path, driver="KML").pipe(clean_cols)
#      27     info_df = pd.read_csv(path2).pipe(clean_cols)
#      28     return pd.merge(df, info_df)
#
# ...
